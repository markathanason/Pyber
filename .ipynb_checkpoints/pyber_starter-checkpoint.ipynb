# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_df = pd.read_csv(city_data_to_load)
city_df["city"] = city_df["city"].astype(str)
ride_df = pd.read_csv(ride_data_to_load)
ride_df["city"] = ride_df["city"].astype(str)
# Combine the data into a single datase
combined_df = pd.merge(city_df, ride_df, on="city", how="left")
combined_df = combined_df[["city", "date", "fare", "ride_id", "driver_count", "type"]]
# Display the data table for preview
combined_df.head()
# Out:
#           city                 date   fare        ride_id  driver_count   type
# 0  Richardfort  2018-02-24 08:40:38  13.93  5628545007794            38  Urban
# 1  Richardfort  2018-02-13 12:46:07  14.00   910050116494            38  Urban
# 2  Richardfort  2018-02-16 13:52:19  17.92   820639054416            38  Urban
# 3  Richardfort  2018-02-01 20:18:28  10.26  9554935945413            38  Urban
# 4  Richardfort  2018-04-17 02:26:37  23.00   720020655850            38  Urban

# %%
groupByCity = combined_df.groupby('city')
city = groupByCity['city'].nunique()
fare_avg = groupByCity['fare'].mean()
fare_count = groupByCity['fare'].sum()
total_rides = groupByCity['ride_id'].count()
total_drivers = groupByCity['driver_count'].max()
city_type = groupByCity['type'].max()
per_city = total_rides / city



byCity_df = pd.DataFrame ({'Average Fare': fare_avg,
                           'Total Rides': fare_count,
                           'Total Drivers': total_drivers,
                           'City Type': city_type,
                           'Fare total': fare_count,
                           'Per City': per_city})

byCity_df.head(20)
# Out:
#                  Average Fare  Total Rides  Total Drivers City Type  \
# city
# Amandaburgh         24.641667       443.55             12     Urban
# Barajasview         25.332273       557.31             26     Urban
# Barronchester       36.422500       582.76             11  Suburban
# Bethanyland         32.956111       593.21             22  Suburban
# Bradshawfurt        40.064000       400.64              7     Rural
# Brandonfort         35.437368       673.31             10  Suburban
# Carriemouth         28.314444       764.49             52     Urban
# Christopherfurt     24.501852       661.55             41     Urban
# Colemanland         30.894545       679.68             23  Suburban
# Davidfurt           31.995882       543.93             23  Suburban
# Deanville           25.842632       491.01             49     Urban
# East Aaronbury      25.661111       230.95              7  Suburban
# East Danielview     31.560588       536.53             22  Suburban
# East Kaylahaven     23.757931       688.98             65     Urban
# East Kentstad       29.823077       387.70             20  Suburban
# East Marymouth      30.835185       832.55              5  Suburban
# Erikaland           24.906667       298.88             37     Urban
# Garzaport           24.123333        72.37              7     Rural
# Grahamburgh         25.221200       630.53             61     Urban
# Grayville           27.763333       416.45              2  Suburban
#
#                  Fare total  Per City
# city
# Amandaburgh          443.55      18.0
# Barajasview          557.31      22.0
# Barronchester        582.76      16.0
# Bethanyland          593.21      18.0
# Bradshawfurt         400.64      10.0
# Brandonfort          673.31      19.0
# Carriemouth          764.49      27.0
# Christopherfurt      661.55      27.0
# Colemanland          679.68      22.0
# Davidfurt            543.93      17.0
# Deanville            491.01      19.0
# East Aaronbury       230.95       9.0
# East Danielview      536.53      17.0
# East Kaylahaven      688.98      29.0
# East Kentstad        387.70      13.0
# East Marymouth       832.55      27.0
# Erikaland            298.88      12.0
# Garzaport             72.37       3.0
# Grahamburgh          630.53      25.0
# Grayville            416.45      15.0

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
#setting types
urban = byCity_df.loc[byCity_df["City Type"] == "Urban", :]
suburban = byCity_df.loc[byCity_df["City Type"] == "Suburban", :]
rural = byCity_df.loc[byCity_df["City Type"] == "Rural", :]

# Build the scatter plots for each city types
plt.scatter(urban["Per City"], urban["Average Fare"], s = urban["Total Drivers"]*10, color = "orange", edgecolor = "black", label = "Urban")
plt.scatter(suburban["Per City"], suburban["Average Fare"], s = suburban["Total Drivers"]*10, color = "blue", edgecolor = "black", label = "Suburban")
plt.scatter(rural["Per City"], rural["Average Fare"], s = rural["Total Drivers"]*10, color = "yellow", edgecolor = "black", label = "Rural")

# Incorporate the other graph properties
plt.grid()
plt.suptitle('Pyber Ride Sharing Data (2016)')
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")

# Create a legend
lgnd = plt.legend(frameon = True, edgecolor = 'black', title = "City Types")
lgnd.legendHandles[0]._sizes = [80]
lgnd.legendHandles[1]._sizes = [80]
lgnd.legendHandles[2]._sizes = [80]

# Incorporate a text label regarding circle size
plt.title("Note: Circle size correlates with driver count per city.", x=1.5, y=0.9)

# Save Figure
plt.savefig('figures/books_read.png')

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
